# %%
import tensorflow as tf
import cv2

# %%
model = tf.keras.models.load_model('cnn_mnist_1.h5')

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 28, 28, 32)        320
#
#  max_pooling2d (MaxPooling2D  (None, 14, 14, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 14, 14, 64)        18496
#
#  max_pooling2d_1 (MaxPooling  (None, 7, 7, 64)         0
#  2D)
#
#  flatten (Flatten)           (None, 3136)              0
#
#  dense (Dense)               (None, 128)               401536
#
#  dense_1 (Dense)             (None, 10)                1290
#
# =================================================================
# Total params: 421,642
# Trainable params: 421,642
# Non-trainable params: 0
# _________________________________________________________________

# %%
import cv2
import numpy as np
#img=np.zeros((28,28),np.uint8)
#cv2.imwrite("1.png",img)

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
img2 = cv2.imread('cv6.png', 0)
img2.shape
#img2=cv2.resize(img2,(28,28))
img2.shape
#img2 = cv2.bitwise_not(img2)
plt.imshow(img2,cmap='gray')

# %%
# img2 = img2.flatten()
img2 = img2 / 255.

# %%
np.array([img2]).shape
img2=np.reshape(img2,(28,28,1))

# %%
out = model.predict(np.array([img2]))
# Out:
# 1/1 [==============================] - 0s 26ms/step

# %%
out
# Out:
# array([[  0.17658518, -12.188234  , -21.808825  ,  -5.264956  ,
#          -7.8382154 ,  12.954737  ,  12.298335  , -18.277105  ,
#           4.9355307 ,  -1.5008001 ]], dtype=float32)

# %%
out[0].argmax()
# Out:
# 5
